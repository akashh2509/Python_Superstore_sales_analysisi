# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Gather and clean the data

# %%
data = pd.read_csv('superstore_dataset2011-2015.csv',encoding='ISO-8859-1')

# %% [markdown]
# ### Explore the data

# %% [markdown]
# ### 1. Display Top 5 Rows of The Dataset

# %%
data.head()
# Out:
#    Row ID         Order ID  Order Date   Ship Date       Ship Mode  \
# 0   42433     AG-2011-2040  01-01-2011  06-01-2011  Standard Class
# 1   22253    IN-2011-47883  01-01-2011  08-01-2011  Standard Class
# 2   48883     HU-2011-1220  01-01-2011  05-01-2011    Second Class
# 3   11731  IT-2011-3647632  01-01-2011  05-01-2011    Second Class
# 4   22255    IN-2011-47883  01-01-2011  08-01-2011  Standard Class
#
#   Customer ID    Customer Name      Segment         City            State  \
# 0    TB-11280  Toby Braunhardt     Consumer  Constantine      Constantine
# 1    JH-15985      Joseph Holt     Consumer  Wagga Wagga  New South Wales
# 2      AT-735    Annie Thurman     Consumer     Budapest         Budapest
# 3    EM-14140     Eugene Moren  Home Office    Stockholm        Stockholm
# 4    JH-15985      Joseph Holt     Consumer  Wagga Wagga  New South Wales
#
#    ...        Product ID         Category Sub-Category  \
# 0  ...  OFF-TEN-10000025  Office Supplies      Storage
# ...

# %%
data.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'City', 'State', 'Country',
#        'Postal Code', 'Market', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %% [markdown]
# ### 2. Check The Last 5 Rows of The Dataset

# %%
data.tail()
# Out:
#        Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 51285   32593  CA-2014-115427  31-12-2014  04-01-2015  Standard Class
# 51286   47594    MO-2014-2560  31-12-2014  05-01-2015  Standard Class
# 51287    8857  MX-2014-110527  31-12-2014  02-01-2015    Second Class
# 51288    6852  MX-2014-114783  31-12-2014  06-01-2015  Standard Class
# 51289   36388  CA-2014-156720  31-12-2014  04-01-2015  Standard Class
#
#       Customer ID     Customer Name    Segment       City             State  \
# 51285    EB-13975        Erica Bern  Corporate  Fairfield        California
# 51286     LP-7095         Liz Preis   Consumer     Agadir  Souss-Massa-Draâ
# 51287    CM-12190  Charlotte Melton   Consumer    Managua           Managua
# 51288    TD-20995     Tamara Dahlen   Consumer     Juárez         Chihuahua
# 51289    JM-15580     Jill Matthias   Consumer   Loveland          Colorado
#
#        ...        Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# ### 3. Find Shape of Our Dataset (Number of Rows And Number of Columns)

# %%
data.shape
# Out:
# (51290, 24)

# %% [markdown]
# ### 4.  Get Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51290 non-null  int64
#  1   Order ID        51290 non-null  object
#  2   Order Date      51290 non-null  object
#  3   Ship Date       51289 non-null  object
#  4   Ship Mode       51290 non-null  object
#  5   Customer ID     51282 non-null  object
#  6   Customer Name   51281 non-null  object
#  7   Segment         51288 non-null  object
#  8   City            51289 non-null  object
#  9   State           51289 non-null  object
#  10  Country         51289 non-null  object
#  11  Postal Code     9987 non-null   float64
#  12  Market          51290 non-null  object
#  13  Region          51290 non-null  object
#  14  Product ID      51290 non-null  object
#  15  Category        51289 non-null  object
#  16  Sub-Category    51289 non-null  object
# ...

# %% [markdown]
# ### 5. Check Null Values In The Dataset

# %%
data.isnull()
# Out:
#        Row ID  Order ID  Order Date  Ship Date  Ship Mode  Customer ID  \
# 0       False     False       False      False      False        False
# 1       False     False       False      False      False        False
# 2       False     False       False      False      False        False
# 3       False     False       False      False      False        False
# 4       False     False       False      False      False        False
# ...       ...       ...         ...        ...        ...          ...
# 51285   False     False       False      False      False        False
# 51286   False     False       False      False      False        False
# 51287   False     False       False      False      False        False
# 51288   False     False       False      False      False        False
# 51289   False     False       False      False      False        False
#
#        Customer Name  Segment   City  State  ...  Product ID  Category  \
# ...

# %%
data.isnull().sum()
# Out:
# Row ID                0
# Order ID              0
# Order Date            0
# Ship Date             1
# Ship Mode             0
# Customer ID           8
# Customer Name         9
# Segment               2
# City                  1
# State                 1
# Country               1
# Postal Code       41303
# Market                0
# Region                0
# Product ID            0
# Category              1
# Sub-Category          1
# Product Name          0
# Sales                20
# Quantity              0
# Discount              0
# Profit                2
# Shipping Cost         6
# Order Priority        0
# dtype: int64

# %% [markdown]
# As the data for Postal Code is not available for most of the entries (41303 out of 51290) so we drop the entire Postal Code column

# %%
data = data.drop(["Postal Code"],axis = 1)

# %%
data
# Out:
#        level_0  index  Order Date   Ship Date       Ship Mode  \
# 0            0      0  01-01-2011  06-01-2011  Standard Class
# 1            1      1  01-01-2011  08-01-2011  Standard Class
# 2            2      2  01-01-2011  05-01-2011    Second Class
# 3            3      3  01-01-2011  05-01-2011    Second Class
# 4            4      4  01-01-2011  08-01-2011  Standard Class
# ...        ...    ...         ...         ...             ...
# 51221    51221  51285  31-12-2014  04-01-2015  Standard Class
# 51222    51222  51286  31-12-2014  05-01-2015  Standard Class
# 51223    51223  51287  31-12-2014  02-01-2015    Second Class
# 51224    51224  51288  31-12-2014  06-01-2015  Standard Class
# 51225    51225  51289  31-12-2014  04-01-2015  Standard Class
#
#           Customer Name      Segment         City             State  \
# 0       Toby Braunhardt     Consumer  Constantine       Constantine
# 1           Joseph Holt     Consumer  Wagga Wagga   New South Wales
# ...

# %% [markdown]
# ### 6. Drop Null or missing Entries from the Dataset

# %%
data.dropna(axis = 0, how = "any",inplace = True)

# %%
data.isnull().sum()
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# City              0
# State             0
# Country           0
# Market            0
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# Quantity          0
# Discount          0
# Profit            0
# Shipping Cost     0
# Order Priority    0
# dtype: int64

# %%
data.shape
# Out:
# (51226, 23)

# %% [markdown]
# ### 7. Check For Duplicate Data and Drop Them

# %%
data.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 51285    False
# 51286    False
# 51287    False
# 51288    False
# 51289    False
# Length: 51290, dtype: bool

# %%
data.duplicated().any()
# Out:
# True

# %%
data.duplicated().sum()
# Out:
# 11

# %%
data.drop_duplicates(inplace = True)

# %%
data.shape
# Out:
# (51279, 23)

# %%
data["Order Priority"].unique()
# Out:
# array(['Medium', 'High', 'Critical', 'Low'], dtype=object)

# %%
data["Order Priority"] = data["Order Priority"].str.replace('High','H')
data["Order Priority"] = data["Order Priority"].str.replace('Low','L')
data["Order Priority"] = data["Order Priority"].str.replace('Medium','M')
data["Order Priority"] = data["Order Priority"].str.replace('Critical','C')

# %%
data[["First Name", "Last Name"]] = data["Customer Name"].str.split(n = 1,expand=True)

# %%
data
# Out:
#        Row ID         Order ID  Order Date   Ship Date       Ship Mode  \
# 0       42433     AG-2011-2040  01-01-2011  06-01-2011  Standard Class
# 1       22253    IN-2011-47883  01-01-2011  08-01-2011  Standard Class
# 2       48883     HU-2011-1220  01-01-2011  05-01-2011    Second Class
# 3       11731  IT-2011-3647632  01-01-2011  05-01-2011    Second Class
# 4       22255    IN-2011-47883  01-01-2011  08-01-2011  Standard Class
# ...       ...              ...         ...         ...             ...
# 51285   32593   CA-2014-115427  31-12-2014  04-01-2015  Standard Class
# 51286   47594     MO-2014-2560  31-12-2014  05-01-2015  Standard Class
# 51287    8857   MX-2014-110527  31-12-2014  02-01-2015    Second Class
# 51288    6852   MX-2014-114783  31-12-2014  06-01-2015  Standard Class
# 51289   36388   CA-2014-156720  31-12-2014  04-01-2015  Standard Class
#
#       Customer ID     Customer Name      Segment         City  \
# ...

# %%
data[data["Quantity"] == 0]
# Out:
# Empty DataFrame
# Columns: [Order Date, Ship Date, Ship Mode, Customer Name, Segment, City, State, Country, Market, Region, Product ID, Category, Sub-Category, Product Name, Sales, Quantity, Discount, Profit, Shipping Cost, Order Priority, First Name, Last Name]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# ### 7 .Get Overall Statistics About The Dataset

# %%
data.describe()
# Out:
#          Row ID     Sales  Quantity  Discount    Profit  Shipping Cost
# count 51226.000 51226.000 51226.000 51226.000 51226.000      51226.000
# mean  25650.127   246.548     3.476     0.143    28.630         26.384
# std   14810.464   487.673     2.279     0.212   174.400         57.301
# min       1.000     0.444     1.000     0.000 -6599.978          0.000
# 25%   12823.250    30.780     2.000     0.000     0.000          2.610
# 50%   25652.500    85.140     3.000     0.000     9.240          7.800
# 75%   38473.750   251.100     5.000     0.200    36.810         24.508
# max   51290.000 22638.480    14.000     0.850  8399.976        933.570

# %% [markdown]
# ### 8. Drop unnecessary columns

# %%
data.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'City', 'State', 'Country',
#        'Postal Code', 'Market', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %%
data=data.drop(['Row ID', 'Order ID','Customer ID'],axis=1)

# %%
data.columns
# Out:
# Index(['Order Date', 'Ship Date', 'Ship Mode', 'Customer Name', 'Segment',
#        'City', 'State', 'Country', 'Market', 'Region', 'Product ID',
#        'Category', 'Sub-Category', 'Product Name', 'Sales', 'Quantity',
#        'Discount', 'Profit', 'Shipping Cost', 'Order Priority', 'First Name',
#        'Last Name'],
#       dtype='object')

# %%
data = data.reset_index()
data
# Out:
#        level_0  index  Order Date   Ship Date       Ship Mode  \
# 0            0      0  01-01-2011  06-01-2011  Standard Class
# 1            1      1  01-01-2011  08-01-2011  Standard Class
# 2            2      2  01-01-2011  05-01-2011    Second Class
# 3            3      3  01-01-2011  05-01-2011    Second Class
# 4            4      4  01-01-2011  08-01-2011  Standard Class
# ...        ...    ...         ...         ...             ...
# 51221    51221  51285  31-12-2014  04-01-2015  Standard Class
# 51222    51222  51286  31-12-2014  05-01-2015  Standard Class
# 51223    51223  51287  31-12-2014  02-01-2015    Second Class
# 51224    51224  51288  31-12-2014  06-01-2015  Standard Class
# 51225    51225  51289  31-12-2014  04-01-2015  Standard Class
#
#           Customer Name      Segment         City             State  \
# 0       Toby Braunhardt     Consumer  Constantine       Constantine
# 1           Joseph Holt     Consumer  Wagga Wagga   New South Wales
# ...

# %%
data.drop(["index"],inplace = True, axis = 1)

# %%
data
# Out:
#        level_0  Order Date   Ship Date       Ship Mode     Customer Name  \
# 0            0  01-01-2011  06-01-2011  Standard Class   Toby Braunhardt
# 1            1  01-01-2011  08-01-2011  Standard Class       Joseph Holt
# 2            2  01-01-2011  05-01-2011    Second Class     Annie Thurman
# 3            3  01-01-2011  05-01-2011    Second Class      Eugene Moren
# 4            4  01-01-2011  08-01-2011  Standard Class       Joseph Holt
# ...        ...         ...         ...             ...               ...
# 51221    51221  31-12-2014  04-01-2015  Standard Class        Erica Bern
# 51222    51222  31-12-2014  05-01-2015  Standard Class         Liz Preis
# 51223    51223  31-12-2014  02-01-2015    Second Class  Charlotte Melton
# 51224    51224  31-12-2014  06-01-2015  Standard Class     Tamara Dahlen
# 51225    51225  31-12-2014  04-01-2015  Standard Class     Jill Matthias
#
#            Segment         City             State        Country  Market  ...  \
# ...

# %%
data.rename(columns = {"level_0" : "index"},inplace = True)

# %%
data
# Out:
#        index  Order Date   Ship Date       Ship Mode     Customer Name  \
# 0          0  01-01-2011  06-01-2011  Standard Class   Toby Braunhardt
# 1          1  01-01-2011  08-01-2011  Standard Class       Joseph Holt
# 2          2  01-01-2011  05-01-2011    Second Class     Annie Thurman
# 3          3  01-01-2011  05-01-2011    Second Class      Eugene Moren
# 4          4  01-01-2011  08-01-2011  Standard Class       Joseph Holt
# ...      ...         ...         ...             ...               ...
# 51221  51221  31-12-2014  04-01-2015  Standard Class        Erica Bern
# 51222  51222  31-12-2014  05-01-2015  Standard Class         Liz Preis
# 51223  51223  31-12-2014  02-01-2015    Second Class  Charlotte Melton
# 51224  51224  31-12-2014  06-01-2015  Standard Class     Tamara Dahlen
# 51225  51225  31-12-2014  04-01-2015  Standard Class     Jill Matthias
#
#            Segment         City             State        Country  Market  ...  \
# ...

# %% [markdown]
# ### Hypothesis 1: Technology products have the highest profit margin compared to other product categories.

# %%
data.columns
# Out:
# Index(['Order Date', 'Ship Date', 'Ship Mode', 'Customer Name', 'Segment',
#        'City', 'State', 'Country', 'Market', 'Region', 'Product ID',
#        'Category', 'Sub-Category', 'Product Name', 'Sales', 'Quantity',
#        'Discount', 'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %%
cat_profit=data.groupby('Category')['Sales'].sum()
cat_profit.plot(kind='bar')
plt.title("Sales by Category")
plt.xlabel("Category")
plt.ylabel("Total Sales")
plt.show()
# Conclusion : The hypothesis is supported as technology products have the
# the highest profit margin of the three categories.

cat_profit=data.groupby('Category')['Profit'].sum()
cat_profit.plot(kind='bar')
plt.title("Profit by Category")
plt.xlabel("Category")
plt.ylabel("Total Profit")
plt.show()
# Conclusion : The hypothesis is supported as technology products have the
# the highest profit margin of the three categories.

# %%
df["Sub-Category"].unique()
# Out:
# array(['Furnishings', 'Bookcases', 'Chairs', 'Tables'], dtype=object)

# %%
df = data[data["Category"] == "Furniture"]
df

# %% [markdown]
# ### Hypothesis 2: The East region has the highest sales compared to other regions.

# %%
data.columns
# Out:
# Index(['Order Date', 'Ship Date', 'Ship Mode', 'Customer Name', 'Segment',
#        'City', 'State', 'Country', 'Market', 'Region', 'Product ID',
#        'Category', 'Sub-Category', 'Product Name', 'Sales', 'Quantity',
#        'Discount', 'Profit', 'Shipping Cost', 'Order Priority', 'First Name',
#        'Last Name'],
#       dtype='object')

# %%
reg_sales=data.groupby('Region')['Sales'].sum()
reg_sales.plot(kind="bar")
plt.title("Total Sales by Region")
plt.xlabel("Region")
plt.ylabel("Total Sales")
plt.show()
# conclusion: The hypothesis is not supported as the central region has
# the highest sales.

# %% [markdown]
# ### Hypothesis 3: Sales are higher during certain months of the year.

# %%
data['Order Month']=pd.DatetimeIndex(data['Order Date']).month
data
# Out:
#        index  Order Date   Ship Date       Ship Mode     Customer Name  \
# 0          0  01-01-2011  06-01-2011  Standard Class   Toby Braunhardt
# 1          1  01-01-2011  08-01-2011  Standard Class       Joseph Holt
# 2          2  01-01-2011  05-01-2011    Second Class     Annie Thurman
# 3          3  01-01-2011  05-01-2011    Second Class      Eugene Moren
# 4          4  01-01-2011  08-01-2011  Standard Class       Joseph Holt
# ...      ...         ...         ...             ...               ...
# 51221  51221  31-12-2014  04-01-2015  Standard Class        Erica Bern
# 51222  51222  31-12-2014  05-01-2015  Standard Class         Liz Preis
# 51223  51223  31-12-2014  02-01-2015    Second Class  Charlotte Melton
# 51224  51224  31-12-2014  06-01-2015  Standard Class     Tamara Dahlen
# 51225  51225  31-12-2014  04-01-2015  Standard Class     Jill Matthias
#
#            Segment         City             State        Country  Market  ...  \
# ...

# %%
month_sales=data.groupby('Order Month')['Sales'].sum()
month_sales.plot(kind='line')
plt.title("Total Sales by Month")
plt.xlabel("Month")
plt.ylabel("Total Sales")
plt.show()
# conclusion : Our Hypothesis is supported as sales are higher
# during certain months of the year.

# %%
data.columns
# Out:
# Index(['index', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer Name',
#        'Segment', 'City', 'State', 'Country', 'Market', 'Region', 'Product ID',
#        'Category', 'Sub-Category', 'Product Name', 'Sales', 'Quantity',
#        'Discount', 'Profit', 'Shipping Cost', 'Order Priority', 'First Name',
#        'Last Name', 'Order Month', 'Order Day'],
#       dtype='object')

# %% [markdown]
# ### Hypothesis 4: Orders with same-day shipping have the lowest rate of returned products.

# %%
data.columns
# Out:
# Index(['Order Date', 'Ship Date', 'Ship Mode', 'Customer Name', 'Segment',
#        'City', 'State', 'Country', 'Market', 'Region', 'Product ID',
#        'Category', 'Sub-Category', 'Product Name', 'Sales', 'Quantity',
#        'Discount', 'Profit', 'Shipping Cost', 'Order Priority', 'Order Month'],
#       dtype='object')

# %%
total_orders_by_shipping_mode=data.groupby('Ship Mode').size()

returned_orders_by_shipping_mode=data[data['Profit']<0].groupby('Ship Mode').size()

returned_per_by_shipping_mode=(returned_orders_by_shipping_mode/total_orders_by_shipping_mode)*100
print(returned_per_by_shipping_mode)
returned_per_by_shipping_mode.plot(kind="bar")
plt.title("Return Per By Shipping Mode")
plt.xlabel("Shipping Mode")
plt.ylabel("Return Per")
plt.show()
# Conclusion: The hypothesis is supported as orders with same-day
# shipping have the lowest rate of returned products.
# Out:
# Ship Mode
# First Class      25.077
# Same Day         23.766
# Second Class     24.094
# Standard Class   24.491
# dtype: float64

# %% [markdown]
# ### Hypothesis 5: The company's profit is more on weekends than on weekdays.

# %%
data.columns
# Out:
# Index(['index', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer Name',
#        'Segment', 'City', 'State', 'Country', 'Market', 'Region', 'Product ID',
#        'Category', 'Sub-Category', 'Product Name', 'Sales', 'Quantity',
#        'Discount', 'Profit', 'Shipping Cost', 'Order Priority', 'First Name',
#        'Last Name', 'Order Month', 'Order Day'],
#       dtype='object')

# %%
data['Order Day']=pd.DatetimeIndex(data['Order Date']).day_name()

day_profit=data.groupby('Order Day')['Profit'].sum()
day_profit.plot(kind="bar")
plt.title("Total Profit by the day of the week")
plt.xlabel("Day of the week")
plt.ylabel("Total Profit")
plt.show()
# conclusion: The hypothesis is not supported as the data shows company's profit
# is higher on weekdays compared to weekends.

# %% [markdown]
# ### Hypothesis 6. Consumer Segment gives more sales but more profit is generated by the Corporate Segment

# %%
# Sales by Segment
segment_sales = data.groupby('Segment')['Sales'].sum()
segment_sales.plot(kind='bar', color='skyblue')
plt.title("Total Sales by Segment")
plt.xlabel("Segment")
plt.ylabel("Total Sales")
plt.show()

# Profit by Segment
segment_profit = data.groupby('Segment')['Profit'].sum()
segment_profit.plot(kind='bar', color='lightgreen')
plt.title("Total Profit by Segment")
plt.xlabel("Segment")
plt.ylabel("Total Profit")
plt.show()

# %% [markdown]
# ### Hypothesis 7. All product sub categories generate more or less but positive results.

# %%
# Sales by Sub-Category
sub_cat_sales = data.groupby('Sub-Category')['Sales'].sum()
sub_cat_sales.plot(kind='bar', figsize=(12, 6), color='coral')
plt.title("Total Sales by Sub-Category")
plt.xlabel("Sub-Category")
plt.ylabel("Total Sales")
plt.xticks(rotation=90)
plt.show()

# Profit by Sub-Category
sub_cat_profit = data.groupby('Sub-Category')['Profit'].sum()
sub_cat_profit.plot(kind='bar', figsize=(12, 6), color='teal')
plt.title("Total Profit by Sub-Category")
plt.xlabel("Sub-Category")
plt.ylabel("Total Profit")
plt.xticks(rotation=90)
plt.show()

# %%
# Filter data for the 'Tables' sub-category
tables_data = data[data['Sub-Category'] == 'Tables']

# Summarize the profit for tables
tables_profit = tables_data['Profit'].sum()
print(f"Total Profit for Tables: {tables_profit}")

# %% [markdown]
# ### Finding the Reason for Losses in the Tables Sub Category

# %%
# Plot profit distribution for tables to verify it is negative
tables_data['Profit'].plot(kind='hist', bins=30, color='red')
plt.title("Profit Distribution for Tables")
plt.xlabel("Profit")
plt.ylabel("Frequency")
plt.show()
# Now we find the correlation bw features and the feature which has most correlation with profits would most probably be the reason for losses.
# Scatter plot for Discount vs Profit
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Discount', y='Profit', data=tables_data, palette='coolwarm')
plt.title("Discount vs Profit for Tables")
plt.xlabel("Discount (in %)")
plt.ylabel("Profit")
plt.show()

# Scatter plot for Shipping Cost vs Profit
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Shipping Cost', y='Profit', data=tables_data, palette='coolwarm')
plt.title("Shipping Cost vs Profit for Tables")
plt.xlabel("Shipping Cost")
plt.ylabel("Profit")
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Discount', y='Profit', size='Shipping Cost', data=tables_data, palette='coolwarm', sizes=(20, 200))
plt.title("Discount and Shipping Cost vs Profit for Tables")
plt.xlabel("Discount (in %)")
plt.ylabel("Profit")
plt.show()

# %% [markdown]
# ### Using the visualizations we are able to draw the following insights -
#
# #### Discount Distribution:
#
# If the histogram shows high discounts frequently, this could be a major factor in the negative profit.
# The scatter plot will indicate how discounts correlate with profit. If higher discounts often correspond to negative profits, it confirms the issue.
#
# #### Shipping Cost Distribution:
#
# The histogram will show if shipping costs are generally high.
# The scatter plot will show the relationship between shipping costs and profit. High shipping costs corresponding to negative profits indicate another problem area.
#
# #### Combined Factors:
#
# The combined scatter plot will show how both high discounts and high shipping costs together affect profit. This can help in understanding if one or both factors are contributing significantly.
